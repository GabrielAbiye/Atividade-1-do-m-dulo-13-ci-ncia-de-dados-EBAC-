# %% [markdown]
# # EBAC - Regressão II - regressão múltipla
#
# ## Tarefa I

# %% [markdown]
# #### Previsão de renda
#
# Vamos trabalhar com a base 'previsao_de_renda.csv', que é a base do seu próximo projeto. Vamos usar os recursos que vimos até aqui nesta base.
#
# |variavel|descrição|
# |-|-|
# |data_ref                | Data de referência de coleta das variáveis |
# |index                   | Código de identificação do cliente|
# |sexo                    | Sexo do cliente|
# |posse_de_veiculo        | Indica se o cliente possui veículo|
# |posse_de_imovel         | Indica se o cliente possui imóvel|
# |qtd_filhos              | Quantidade de filhos do cliente|
# |tipo_renda              | Tipo de renda do cliente|
# |educacao                | Grau de instrução do cliente|
# |estado_civil            | Estado civil do cliente|
# |tipo_residencia         | Tipo de residência do cliente (própria, alugada etc)|
# |idade                   | Idade do cliente|
# |tempo_emprego           | Tempo no emprego atual|
# |qt_pessoas_residencia   | Quantidade de pessoas que moram na residência|
# |renda                   | Renda em reais|

# %%
import pandas as pd
import numpy as np
import patsy
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
df = pd.read_csv(r'C:\Users\Gabriel\Documents\Data Science\Data Science EBAC\Módulo 13\previsao_de_renda.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             15000 non-null  int64
#  1   data_ref               15000 non-null  object
#  2   id_cliente             15000 non-null  int64
#  3   sexo                   15000 non-null  object
#  4   posse_de_veiculo       15000 non-null  bool
#  5   posse_de_imovel        15000 non-null  bool
#  6   qtd_filhos             15000 non-null  int64
#  7   tipo_renda             15000 non-null  object
#  8   educacao               15000 non-null  object
#  9   estado_civil           15000 non-null  object
#  10  tipo_residencia        15000 non-null  object
#  11  idade                  15000 non-null  int64
#  12  tempo_emprego          12427 non-null  float64
#  13  qt_pessoas_residencia  15000 non-null  float64
# ...

# %% [markdown]
# 1. Ajuste um modelo para prever log(renda) considerando todas as covariáveis disponíveis.
#     - Utilizando os recursos do Patsy, coloque as variáveis qualitativas como *dummies*.
#     - Mantenha sempre a categoria mais frequente como casela de referência
#     - Avalie os parâmetros e veja se parecem fazer sentido prático.
#
# 2. Remova a variável menos significante e analise:
#     - Observe os indicadores que vimos, e avalie se o modelo melhorou ou piorou na sua opinião.
#     - Observe os parâmetros e veja se algum se alterou muito.
#
# 3. Siga removendo as variáveis menos significantes, sempre que o *p-value* for menor que 5%. Compare o modelo final com o inicial. Observe os indicadores e conclua se o modelo parece melhor.

# %%
y , X = patsy.dmatrices( + C(tipo_renda) + C(educacao) \
+ C(estado_civil) + C(tipo_residencia)' , data = df)
reg = sm.OLS(y , X).fit()
# Out:
#   Cell In[164], line 2
#     + C(estado_civil) + C(tipo_residencia)' , data = df)
#                                           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
reg.summary()

# %%
y, X = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment("F")) \
                        + C(posse_de_veiculo, Treatment(False)) \
                        + C(tipo_renda, Treatment("Assalariado")) \
                        + C(posse_de_imovel, Treatment(True)) \
                        + C(educacao, Treatment("Secundário")) \
                        + C(estado_civil, Treatment("Casado"))\
                        + C(tipo_residencia , Treatment("Casa"))', data=df)

# %%
reg = sm.OLS(y , X).fit()
reg.summary()

# %%
y, X = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment("F")) \
                        + C(tipo_renda, Treatment("Assalariado")) \
                        + C(posse_de_imovel, Treatment(True)) \
                        + C(educacao, Treatment("Secundário")) \
                        + C(estado_civil, Treatment("Casado"))\
                        + C(tipo_residencia , Treatment("Casa"))', data=df)

# %%
reg = sm.OLS(y , X).fit()
reg.summary()

# %%
df = df[df['educacao'] != 'Primário']
y, X = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment("F")) \
                        + C(tipo_renda, Treatment("Assalariado")) \
                        + C(posse_de_imovel, Treatment(True)) \
                        + C(educacao, Treatment("Secundário")) \
                        + C(estado_civil, Treatment("Casado"))\
                        + C(tipo_residencia , Treatment("Casa"))', data=df)

# %%
reg = sm.OLS(y , X).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.162
# Model:                            OLS   Adj. R-squared:                  0.161
# Method:                 Least Squares   F-statistic:                     159.3
# Date:                Mon, 27 May 2024   Prob (F-statistic):               0.00
# Time:                        20:55:15   Log-Likelihood:                -17919.
# No. Observations:               14835   AIC:                         3.588e+04
# Df Residuals:                   14816   BIC:                         3.602e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
df = df[df['educacao'] != 'Pós graduação']
y, X = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment("F")) \
                        + C(tipo_renda, Treatment("Assalariado")) \
                        + C(posse_de_imovel, Treatment(True)) \
                        + C(educacao, Treatment("Secundário")) \
                        + C(estado_civil, Treatment("Casado"))\
                        + C(tipo_residencia , Treatment("Casa"))', data=df)
reg = sm.OLS(y , X).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.162
# Model:                            OLS   Adj. R-squared:                  0.161
# Method:                 Least Squares   F-statistic:                     168.4
# Date:                Mon, 27 May 2024   Prob (F-statistic):               0.00
# Time:                        20:56:26   Log-Likelihood:                -17895.
# No. Observations:               14809   AIC:                         3.583e+04
# Df Residuals:                   14791   BIC:                         3.596e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
df = df[df['tipo_renda'] != 'Bolsista']
y, X = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment("F")) \
                        + C(tipo_renda, Treatment("Assalariado")) \
                        + C(posse_de_imovel, Treatment(True)) \
                        + C(educacao, Treatment("Secundário")) \
                        + C(estado_civil, Treatment("Casado"))\
                        + C(tipo_residencia , Treatment("Casa"))', data=df)
reg = sm.OLS(y , X).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.162
# Model:                            OLS   Adj. R-squared:                  0.161
# Method:                 Least Squares   F-statistic:                     178.8
# Date:                Mon, 27 May 2024   Prob (F-statistic):               0.00
# Time:                        20:57:22   Log-Likelihood:                -17888.
# No. Observations:               14800   AIC:                         3.581e+04
# Df Residuals:                   14783   BIC:                         3.594e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
df = df[df['tipo_residencia'] != 'Governamental']
y, X = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment("F")) \
                        + C(tipo_renda, Treatment("Assalariado")) \
                        + C(posse_de_imovel, Treatment(True)) \
                        + C(educacao, Treatment("Secundário")) \
                        + C(estado_civil, Treatment("Casado"))\
                        + C(tipo_residencia , Treatment("Casa"))', data=df)
reg = sm.OLS(y , X).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     189.2
# Date:                Mon, 27 May 2024   Prob (F-statistic):               0.00
# Time:                        20:58:02   Log-Likelihood:                -17329.
# No. Observations:               14355   AIC:                         3.469e+04
# Df Residuals:                   14339   BIC:                         3.481e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
df = df[df['estado_civil'] != 'Viúvo']
y, X = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment("F")) \
                        + C(tipo_renda, Treatment("Assalariado")) \
                        + C(posse_de_imovel, Treatment(True)) \
                        + C(educacao, Treatment("Secundário")) \
                        + C(estado_civil, Treatment("Casado"))\
                        + C(tipo_residencia , Treatment("Casa"))', data=df)
reg = sm.OLS(y , X).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     193.5
# Date:                Mon, 27 May 2024   Prob (F-statistic):               0.00
# Time:                        20:58:44   Log-Likelihood:                -16594.
# No. Observations:               13680   AIC:                         3.322e+04
# Df Residuals:                   13665   BIC:                         3.333e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
df = df[df['tipo_residencia'] != 'Comunitário']
y, X = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment("F")) \
                        + C(tipo_renda, Treatment("Assalariado")) \
                        + C(posse_de_imovel, Treatment(True)) \
                        + C(educacao, Treatment("Secundário")) \
                        + C(estado_civil, Treatment("Casado"))\
                        + C(tipo_residencia , Treatment("Casa"))', data=df)
reg = sm.OLS(y , X).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     207.2
# Date:                Mon, 27 May 2024   Prob (F-statistic):               0.00
# Time:                        20:59:34   Log-Likelihood:                -16532.
# No. Observations:               13627   AIC:                         3.309e+04
# Df Residuals:                   13613   BIC:                         3.320e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
df = df[df['estado_civil'] != 'Solteiro']
y, X = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment("F")) \
                        + C(tipo_renda, Treatment("Assalariado")) \
                        + C(posse_de_imovel, Treatment(True)) \
                        + C(educacao, Treatment("Secundário")) \
                        + C(estado_civil, Treatment("Casado"))\
                        + C(tipo_residencia , Treatment("Casa"))', data=df)
reg = sm.OLS(y , X).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     208.3
# Date:                Mon, 27 May 2024   Prob (F-statistic):               0.00
# Time:                        21:00:04   Log-Likelihood:                -14437.
# No. Observations:               11915   AIC:                         2.890e+04
# Df Residuals:                   11902   BIC:                         2.900e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
df = df[df['tipo_residencia'] != 'Aluguel']
y, X = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment("F")) \
                        + C(tipo_renda, Treatment("Assalariado")) \
                        + C(posse_de_imovel, Treatment(True)) \
                        + C(educacao, Treatment("Secundário")) \
                        + C(estado_civil, Treatment("Casado"))\
                        + C(tipo_residencia , Treatment("Casa"))', data=df)
reg = sm.OLS(y , X).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     225.4
# Date:                Mon, 27 May 2024   Prob (F-statistic):               0.00
# Time:                        21:00:45   Log-Likelihood:                -14259.
# No. Observations:               11780   AIC:                         2.854e+04
# Df Residuals:                   11768   BIC:                         2.863e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...
